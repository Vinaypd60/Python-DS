# %% [markdown]
# # Introduction
# ## Python is highly recommended programming language & object oriented lang.
# ## Father of python is guido van rossum.
# ## Python developed in NRI(netherlands).
# ## Python was released on 1989 officially released on 1991.
# ## It has large and comprehension standard libraries.
# ## Python is dynamic programming language.
# ## In python everything is done by PVM(Python virtual machine).

# %% [markdown]
# # Versions of Python
# ## Python programming contains 3-types of versions.
# ### a) Python 1.X
# ### b) Python 2.X Here X represents 1 2 3 4
# ### c) python 3.X does not contain backword compartability with python 3.X
#
# ### Python version 3.13.5
# ### 3 - Major version
# ### 13 - Minor version
# ### 5 - Alpha version

# %% [markdown]
# # Python programming inspired from
# ## Functional program from C-Lang
# ## Oops from C++
# ## Modular program from Modulo
# ## Scripting programming from PERL

# %% [markdown]
# # Features of python
# ## Features of a programming language is nothing but services/facilities provided by python.
# ### sample
# ### freeware & opensource
# ### platform independent
# ### dynamically typed
# ### Interpreted & compiler
# ### High-level
# ### Extensible
# ### Embedded
# ### Robust(stron)
# ### Both functional and oops

# %% [markdown]
# # What is Interpreter vs compiler
#
# ## Interpreter = It is nothing but code will execute line by line (or) selection of code(select)
# ## Compiler = Entire code run at a time.

# %% [markdown]
# # Variables = Identifiers = Objects all are same

# %% [markdown]
# # Rules of using variables:
# ## 1) Variable cannot be starts with digit but ends with digit
# ## 2) Variables are case-sensitive
# ## 3) Keywords - reserved words are not define in variable
# ## 4) No special characters is allowed in a variable
# ## 5) Only undserscore is allowed(_)

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Variable = Identifier = Object
#
# ## syntax: varname = value

# %%
# Rule-1 = Var name starts with alphabet & ends with digit
v = 34 # Here v is var and 34 is value
v
# Out:
# 34

# %%
v1 = 8
v1
# Out:
# 8

# %%
v2 = 20
v2
# Out:
# 20

# %%
# Rule-2 = Var is a case-sensitive
v3 = 56
V3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Rule-2 = Var is a case-sensitive
#       2 v3 = 56
# ----> 3 V3
#
# NameError: name 'V3' is not defined

# %%
# Python reserved words(keywords) are not defined as a var

if = 32
if
# Out:
#   Cell In[6], line 3
#     if = 32
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
try = 45
try
# Out:
#   Cell In[9], line 1
#     try = 45
#         ^
# SyntaxError: expected ':'

# %%
For = 34
For
# Out:
# 34

# %%
# No spcl char is allowed except underscore(_)
v@ = 34
v@
# Out:
#   Cell In[11], line 2
#     v@ = 34
#        ^
# SyntaxError: invalid syntax

# %%
v_ = 56
v_
# Out:
# 56
