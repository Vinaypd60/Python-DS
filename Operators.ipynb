# %% [markdown]
# # An operator is an symbol which will perform an operation on DATA (or) VALUES (or) OBJECT.
# ## + = operators
# # If two or more variables or values connected with an operator then it is called 'Expressions'.
# ## Operator = a + b * c
#
# # In python programming, we have 7 types of operators. they are
# ## a) Arithmetic operator
# ## b) Assignment operator
# ## c) Relational operator
# ## d) Logical operator
# ## e) Bitwise operator
# ## f) Membership operator(in and not in)
# ## g) Identity operator(is and is not)
#
# # Note: Python does not support unary operator(++) and (--) and ternary operator(?:)
# # Note: Python programming supports "short hand operator"

# %% [markdown]
# # Arithmetic operator

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
print(a - b)
# Out:
# 5

# %%
print(a * b)
# Out:
# 50

# %%
print(a / b)
# Out:
# 2.0

# %%
print(a // b)
# Out:
# 2

# %%
print(a ** b)
# Out:
# 100000

# %%
print(a % b)
# Out:
# 0

# %% [markdown]
# # Assignment operator

# %%
x = 2

# %%
x = x + 2
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 8

# %%
x *= 2
x
# Out:
# 16

# %%
x /=2
x
# Out:
# 8.0

# %%
x //=2
x
# Out:
# 4.0

# %% [markdown]
# # Unary operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational operator

# %%
a = 10
b = 2

# %%
print(a > b)
# Out:
# True

# %%
print(a < b)
# Out:
# False

# %%
print(a == b)
# Out:
# False

# %%
print(a != b)
# Out:
# True

# %%
print(a <= b)
# Out:
# False

# %%
print(a >= b)
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
10 > 2 and 10 > 30
# Out:
# False

# %%
10 > 20 and 20 > 10
# Out:
# False

# %%
10 > 2 and 30 > 20
# Out:
# True

# %%
10 > 20 and 20 > 30 and 10 > 4
# Out:
# False

# %%
100 and 200
# Out:
# 200

# %%
100 and 0
# Out:
# 0

# %%
-24 and -34
# Out:
# -34

# %%
100 and 10 and 1
# Out:
# 1

# %% [markdown]
# # Bitwise operator

# %% [markdown]
# # In python programming, we have 6-types of bitwise operator.
# - complement
# - and
# - OR
# - XOR
# - Left shift <<
# - Right shift >>

# %% [markdown]
# # 1) complement

# %%
~ 23
# Out:
# -24

# %%
~ 34
# Out:
# -35

# %%
~ 67
# Out:
# -68

# %%
~ 56
# Out:
# -57

# %% [markdown]
# # & Bitwise operator

# %%
0 & 1
# Out:
# 0

# %%
1 & 0
# Out:
# 0

# %%
1 & 1
# Out:
# 1

# %%
0 & 0
# Out:
# 0

# %%
a = 10
b = 4
c = a & b
print(c)
# Out:
# 0

# %%
13 & 14
# Out:
# 12

# %%
12 & 13
# Out:
# 12

# %% [markdown]
# # Bitwise |(OR)

# %%
a = 10
b = 4
c = a | b
print(c)
# Out:
# 14

# %%
12 | 13
# Out:
# 13

# %%
s1 = {10,20,30}
s2 = {15,10,25}
s3 = s1 | s2
print(s3)
# Out:
# {20, 25, 10, 30, 15}

# %% [markdown]
# # XOR (^)

# %%
1 ^ 0
# Out:
# 1

# %%
12 ^ 13
# Out:
# 1

# %%
1 ^ 1
# Out:
# 0

# %%
8 ^ 2
# Out:
# 10

# %%
4 ^ 3
# Out:
# 7

# %%
6 ^ 5
# Out:
# 3

# %%
40 ^ 35
# Out:
# 11

# %% [markdown]
# # BITWISE LEFT SHIFT

# %%
a = 10
b = 3
c = a << b
print(c)
# Out:
# 80

# %%
12 << 5
# Out:
# 384

# %%
32 << 7
# Out:
# 4096

# %% [markdown]
# - The bitwise left shift operator execution process(<<) it removes no.of bits towards the left sideby adding no.of zeros at right side.

# %% [markdown]
# # Bitwise right shift operator

# %%
a = 10
b = 3
c = a >> b
print(c)
# Out:
# 1

# %%
14 >> 6
# Out:
# 0

# %%
13 >> 6
# Out:
# 0

# %%
15 >> 9
# Out:
# 0
