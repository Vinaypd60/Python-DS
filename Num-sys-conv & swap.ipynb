# %% [markdown]
# # In any programming language, we have 4-types of Number stystem conversion.
# ## 1) Decimal number system
# ## 2) Binary number system
# ## 3) Octal number system
# ## 4) Hexa number system

# %% [markdown]
# # Binary

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(34)
# Out:
# '0b100010'

# %%
int(0b11001)
# Out:
# 25

# %%
int(0b100010)
# Out:
# 34

# %% [markdown]
# # Octal

# %%
oct(25)
# Out:
# '0o31'

# %%
oct(34)
# Out:
# '0o42'

# %%
int(0o31)
# Out:
# 25

# %%
int(0o42)
# Out:
# 34

# %% [markdown]
# # Hexa

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
hex(342)
# Out:
# '0x156'

# %%
int(0x156)
# Out:
# 342

# %%
0xf # Ip address never cross after F
# Out:
# 15

# %% [markdown]
# # Swapping techniques

# %%
a = 5
b = 10

# %%
print(a+b)
# Out:
# 15

# %%
a,b = b,a
